# %%
import numpy as np
import scipy as sci
import matplotlib.pyplot as plt
from jinja2 import Template
from pyne import data
from pyne.material import Material
from pyne import serpent
from pyne import nucname
import pdb
import cv2
import pandas as pd
from palettable.cartocolors.qualitative import Pastel_6
from palettable.cartocolors.qualitative import Safe_10

# %% [markdown]
# First we want the helium density in $10^24$ atoms per cc.
#
# \begin{align}
# PV&=nRT\\
# \frac{n}{V}&=\frac{P}{RT}
# \end{align}

# %%
R = 8.314 # j/k-mol
temp = [250 ,750] #celsius
pres = [6*10**6, 5.84*10**6] #pascals
hedensity = np.zeros(len(temp))


for i, t in enumerate(temp):
    hedensity[i] = ((pres[i])/((t+273.15)*R)) # mol/m^3 

hedensavg = np.sum(hedensity)/len(hedensity)*(6.022*10**-7)# 10^24/cc

print(hedensavg)
# Out:
# 0.000622077124202638

# %% [markdown]
# ### Isotopic composition of the fuel
#
# The enrichment of the UCO kernels in the TRISO particles is known.  Additionally, we know the molar contentrations of the three compounds that make UCO: $UO_2$ , $UC$, and $UC_{1.86}$. The [PyNE](https://pyne.io/) python library is used to create the material cards for the fuel.
# <br>
# UCO is created from $UO_2$, $UC$, and $UC_{1.86}$ in molar concentrations of 0.714, 0.164, and 0.123, respectively.

# %%
leu = Material({'U235': 0.1975 , 'U238': 0.8025})
uo2 = Material()
uc = Material()
uc186 = Material()

uo2.from_atom_frac({'O16': 2.0 , leu :1.0})
uc.from_atom_frac({'C12':1, leu: 1.0})
uc186.from_atom_frac({'C12':1.86, leu : 1.0})

uco = Material()
uco.from_atom_frac({uo2: 0.714, uc: 0.164, uc186: 0.123})
print(uco) #the negative values for composition mean it is mass fraction, just like serpent

print()
print(uco.to_atom_frac())

print()

uco.atoms_per_molecule = -1.0
print(uco.to_atom_frac())
# Out:
# Material:
# mass = 265.24240005376
# density = -1.0
# atoms per molecule = 2.8217800000000004
# ---------------------------------------
# C12    0.017770009617786166
# O16    0.08611269567821504
# U235   0.17698316570403982
# U238   0.7191341289999591
#
# {60120000: 0.3927800000000001, 80160000: 1.4280000000000002, 922350000: 0.19972198389445162, 922380000: 0.8012780161055485}
#
# {60120000: 0.13919582674765577, 80160000: 0.5060635485402832, 922350000: 0.07077872261283714, 922380000: 0.28396190209922406}

# %% [markdown]
# In order to find the core dimensions, I used an image of the reactor core given in a public presentation to the NRC.
# <br>
# Then, I opened it in an image viewer that gave the cursor's coordinates in pixels, measured the reactor core features in pixels.  Knowing the outer core diameter, developed a scale between pixels and meters, and used that to determine the core geometry.
#
# \begin{align}
# s (\frac{cm}{px}) = 100* \frac{RPV_D (m)}{RPV_D (px)}\\
# x (cm) = x (px) * scale
# \end{align}

# %%
core_dm = 4.88 # m
core_dpx = 69 #px
scale = core_dm/core_dpx *100 # cm/px

inner_corerad_px = 17.5
inner_corerad_cm = inner_corerad_px *scale
reflect_px = 13
reflect_cm = reflect_px *scale

print(2*(reflect_cm+inner_corerad_cm)) #can't be more than 488, which is the diameter including RPV
print()
print(inner_corerad_cm)
print(reflect_cm)
print(inner_corerad_cm+reflect_cm)
# Out:
# 431.4202898550724
#
# 123.76811594202897
# 91.94202898550724
# 215.7101449275362

# %% [markdown]
# I found the midpoint of the cones on the top and bottom , and used the distance between these two midpoints as an adjusted height.  Then, I simplified by letting the reflector directly surround this region.

# %% [markdown]
# ### Creating the input file
#
# The first step to creating the input file is to create the pebble and particle location input cards.  This can be done using serpent's built in particle dispersal routine, which takes the dimensions of the particle, the volume they are dispersed in, and the particle number or packing fraction, the universe the particles are in, and creates a plain text file, where each line is:
#
# \begin{align}
# x-coordinate\ \ y-coordinate\ \  z-coordinate\ \  universe
# \end{align}
#
# In order to split the automatically generated distribution file into several sub-files for modeling different fuel compositions, the cell below splits a given text file into multiple.  It can also append a character to the universe name, if needed.

# %% [markdown]
# origin = open('htgr-20/6012345/all-pebbs.inp','r')
#
# filenames = ['htgr-20/6012345/pbbls-0.inp',
#              'htgr-20/6012345/pbbls-1.inp',
#              'htgr-20/6012345/pbbls-2.inp',
#              'htgr-20/6012345/pbbls-3.inp',
#              'htgr-20/6012345/pbbls-4.inp',
#              'htgr-20/6012345/pbbls-5.inp',
#              'htgr-20/6012345/pbbls-6.inp']
#
# lines = 0
# for line in list(origin):
#     lines += 1
# origin.seek(0)
# i = 0
#
# file = ['f0','f1','f2','f3','f4','f5','f6']
# for index, name in enumerate(filenames):
#     file[index] = open(name,'a+')
# subuniverse = ['a','b','c','d']
#
# while i < lines:
#     for index, f in enumerate(file):
#         #use lines below if you need to append a new character to universe name
#         #newline = origin.readline()
#         #f.write(newline[:-1] + subuniverse[index] + newline[-1:])
#         f.write(origin.readline())
#         i += 1
#         if i == lines:
#             break
# for f in file:
#     f.close()
# origin.close()

# %% [markdown]
# After the above is used to create the input file, it is run in the terminal with Serpent 2.1.31

# %%
dep = serpent.parse_dep('../single-pebble/burn-20/htgr-mr-burn-20.inp_dep.m')

# %%
mats = dep['MAT_fuel_MATERIAL']
#mats[1].comp.keys
newdict = {nucname.serpent(k): v for k,v in mats[0].comp.items()}

for k,v in newdict.items():
    print('{}.08c'.format(k),"     " ,v)
# Out:
# H-1.08c       0.0
# H-2.08c       0.0
# H-3.08c       0.0
# He-3.08c       0.0
# He-4.08c       0.0
# Li-6.08c       0.0
# Li-7.08c       0.0
# Be-9.08c       0.0
# B-10.08c       0.0
# B-11.08c       0.0
# C-nat.08c       0.017761272727272726
# N-14.08c       0.0
# N-15.08c       0.0
# O-16.08c       0.08606599999999999
# O-17.08c       0.0
# Ca-46.08c       0.0
# Ca-48.08c       0.0
# Ti-47.08c       0.0
# Ti-48.08c       0.0
# Ti-49.08c       0.0
# Ti-50.08c       0.0
# Cr-52.08c       0.0
# Cr-53.08c       0.0
# Cr-54.08c       0.0
# Mn-55.08c       0.0
# Fe-56.08c       0.0
# Fe-57.08c       0.0
# Fe-58.08c       0.0
# Co-58.08c       0.0
# Co-59.08c       0.0
# Ni-60.08c       0.0
# Ni-61.08c       0.0
# Ni-62.08c       0.0
# Ni-64.08c       0.0
# Cu-63.08c       0.0
# Cu-65.08c       0.0
# Ge-70.08c       0.0
# Ge-72.08c       0.0
# Ge-73.08c       0.0
# Ge-74.08c       0.0
# Ge-76.08c       0.0
# As-75.08c       0.0
# Se-74.08c       0.0
# Se-76.08c       0.0
# ...

# %%
serpent.parse_res('../full-core/htgr-20/htgr-20-full-core.inp_res.m')
# Out:
# {'np': <module 'numpy' from '/home/zoe/anaconda3/lib/python3.7/site-packages/numpy/__init__.py'>,
#  'TOT_FLUX': array([[9.3077e+02, 3.5800e-03]]),
#  'TOT_CUTRATE': array([[0., 0.]]),
#  'PU239_CAPT': array([[0.0191427, 0.02283  , 0.0424034, 0.02234  ]]),
#  'ANA_INV_SPD': array([[1.51219e-06, 2.35000e-03]]),
#  'RES_MEMSIZE': array([30.69]),
#  'URES_DILU_CUT': array([1.e-09]),
#  'SRC_NORM_MODE': array([2]),
#  'TOT_RR': array([[3.1922e+02, 4.5900e-03]]),
#  'ANA_EALF': array([[1.78105e-07, 1.31000e-02]]),
#  'TOT_NUCLIDES': array([316]),
#  'PU240_FISS': array([[1.91763e-05, 7.03540e-01, 4.48023e-05, 7.03600e-01]]),
#  'ADJ_NAUCHI_LIFETIME': array([[0.00100877, 0.00856   , 0.00100924, 0.00871   , 0.00082817,
#          0.12952   ]]),
#  'TOT_SF_RATE': array([0.]),
#  'ANA_THERM_TIME': array([[0.00182407, 0.00564   , 0.0018247 , 0.00566   , 0.00169437,
#          0.08766   ]]),
#  'TOT_CELLS': array([4]),
#  'ELECTRON_DECAY_SOURCE': array([0.]),
# ...

# %%
fuel = (4/3)*np.pi*(0.02125**3)*(18000)
pyroc = 18000*( ((4/3)*np.pi*(0.03475**3) - 
                 (4/3)*np.pi*(0.03075**3))
         + ( (4/3)*np.pi*(0.04225**3) - 
            (4/3)*np.pi*(0.03828**3) ))
sic = ((4/3)*np.pi*(0.03825**3) - (4/3)*np.pi*(0.03475**3))*18000

graph = ((4/3)*np.pi*(3.0**3)) - fuel - pyroc - sic

tot = (4/3)*np.pi*(3.0**3)

# %%
print(fuel/tot)
print(pyroc/tot)
print(sic/tot)
print(graph/tot)
# Out:
# 0.006397135416666668
# 0.021474480715333345
# 0.009332895833333325
# 0.9627954880346667

# %%
(fuel+pyroc+sic+graph)/tot
# Out:
# 1.0

# %% [markdown]
# $$\text{Power Density} = \frac{kW}{g_{fuel}} $$
#
# For 200 MWth:
#
# $$\text{Power Density} = \frac{200*1000}{\frac{4}{3} \pi 0.02125^3*220000*18000} = 0.11 $$
#
# Therefore, for 20 MWth
#
# $$ 0.11 {kW/g} = \frac{20*1000}{m_{fuel}}$$
#
# $$m_{fuel} = 181818.18 [g]$$
#
# $$V_{fuel,core} = \frac{m_{fuel}[g]}{\rho_{fuel}[\frac{g}{cc}]} = \frac{181818.18}{11.0} = 16528.92 [cc]$$
#
# $$ V_{fuel,pebble} = 18000 * \frac{4}{3} \pi 0.02125^{3} = 0.7235$$
#
# $$ n_{pebbles} = \frac{V_{fuel,core}}{V_{fuel,pebble}} = \frac{16528.92}{0.7235} = 22846 $$
#
# $\phi$, the packing fraction, is the ratio of the objects in a 3-D space to the volume of that space, and for a random pack, between 0.56 and 0.60 are acceptable:
#
# $$ \phi = \frac{22846 * \frac{4}{3}\pi r_{pebble}^3}{V_{core}} = [0.56,0.58,0.60] $$
#
# $$ V_{core} = [4306369.55, 4454865.05, 4613967.37] = H_{core} * \pi * R_{core}^{2} $$
#
# $$ H = \frac{V}{\pi*R^{2}} $$

# %%
t_vol_peb = 22846*4/3*np.pi*3.0**3
print(t_vol_peb/0.60)
print(t_vol_peb/0.58)
print(t_vol_peb/0.56)
# Out:
# 4306369.545834744
# 4454865.047415253
# 4613967.370537226

# %%
R = np.linspace(50,170)
H060 = 4306369.55/(np.pi*R**2)
H058 = 4454865.05/(np.pi*R**2)
H056 = 4613967.37/(np.pi*R**2)
print(4306369.55/(np.pi*80**2))
print(4454865.05/(np.pi*80**2))
print(4613967.37/(np.pi*80**2))
plt.plot(R,H060, linestyle = ':')
plt.plot(R,H058, linestyle = '-.')
plt.plot(R,H056)
plt.plot(90,180, marker = 'o')
plt.title('Possible Radius versus Height Curves for Sangamon20')
plt.xlabel('Radius [cm]')
plt.ylabel('Height [cm]')
plt.legend(['$\eta_{pf}$ = 0.60','$\eta_{pf}$ = 0.58','$\eta_{pf}$ = 0.56'])
# Out:
# 214.18125020716278
# 221.56681047338233
# 229.47991068756625

# %% [markdown]
# In order to determine the outward surface current, the result for the current given by Serpent's surface detector must be divided by the surface area of the detector, to get units of $\frac{n}{cm^2s}$

# %%
r20det = 164 #detector radius, cm
h20det = 2*164 #detector height, cm

sa20det = (2*r20det*np.pi*h20det)+ 2*(np.pi*r20det**2) #detector surface area, cm

print(sa20det)
# Out:
# 506977.6560657064

# %% [markdown]
# The formula for the outward current at the reflector surface is then
# $$ J^+[\frac{n}{cm^2s}] = \frac{J^+[\frac{n}{s}]}{S_{det}[cm^2]} $$
# The error becomes:
# $$ \delta J^+[\frac{n}{cm^2s}] = |\frac{1}{S_{det}}|\delta J^+[\frac{n}{s}] $$

# %% [markdown]
# For the values below, the model run was:
#
# - 20 MWth core
# - 65 cm reflector thickness on sides and top, for a current surface detector radius of 164 cm, and a height of 328 cm
# - 50,000 neutrons, 100/50 active/inactive cycles
# - A $\frac{1}{6}$ slice of the core is used with a periodic boundary condition

# %%
J_0_60 = 3.002 * 10**17
delJ_0_60 = 0.00147
J_0_60c = J_0_60/sa20det
delJ_0_60c = (delJ_0_60/sa20det)*J_0_60c
print("0-60: " + "{:.3e}".format(J_0_60c) + " +/- " + "{:.3e}".format(delJ_0_60c))
print()

J_60_120 = 2.983 * 10**17
delJ_60_120 = 0.00141
J_60_120c = J_60_120/sa20det
delJ_60_120c = (delJ_60_120/sa20det)*J_60_120c
print("60-120: " + "{:.3e}".format(J_60_120c) + " +/- " + "{:.3e}".format(delJ_60_120c))
print()

J_120_180 = 2.995 * 10**17
delJ_120_180 = 0.00126
J_120_180c = J_120_180/sa20det
delJ_120_180c = (delJ_120_180/sa20det)*J_120_180c
print("120-180: " + "{:.3e}".format(J_120_180c) + " +/- " + "{:.3e}".format(delJ_120_180c))
print()

J_180_240 = 2.996 * 10**17
delJ_180_240 = 0.00147
J_180_240c = J_180_240/sa20det
delJ_180_240c = (delJ_180_240/sa20det)*J_180_240c
print("180-240: " + "{:.3e}".format(J_180_240c) + " +/- " + "{:.3e}".format(delJ_180_240c))
print()

J_240_300 = 2.983 * 10**17
delJ_240_300 = 0.00151
J_240_300c = J_240_300/sa20det
delJ_240_300c = (delJ_240_300/sa20det)*J_240_300c
print("240-300: " + "{:.3e}".format(J_240_300c) + " +/- " + "{:.3e}".format(delJ_240_300c))
print()

J_300_360 = 2.985 * 10**17
delJ_300_360 = 0.00144
J_300_360c = J_300_360/sa20det
delJ_300_360c = (delJ_300_360/sa20det)*J_300_360c
print("300-360: " + "{:.3e}".format(J_300_360c) + " +/- " + "{:.3e}".format(delJ_300_360c))
print()
# Out:
# 0-60: 5.921e+11 +/- 1.717e+03
#
# 60-120: 5.884e+11 +/- 1.636e+03
#
# 120-180: 5.908e+11 +/- 1.468e+03
#
# 180-240: 5.910e+11 +/- 1.713e+03
#
# 240-300: 5.884e+11 +/- 1.752e+03
#
# 300-360: 5.888e+11 +/- 1.672e+03

# %% [markdown]
# A control run was also made, with all parameters the same as the model the slices came from, but I full core model instead.  The resulting outer $J^+$ is:

# %%
J_20 = 2.98331E+17
delJ_20 = 0.00135
J_20c = J_20/sa20det
delJ_20c = delJ_20/sa20det
print("Full 20 MWth Core: " + "{:.3e}".format(J_20c) + " +/- " + "{:.3e}".format(delJ_20c))
print()
# Out:
# Full 20 MWth Core: 5.884e+11 +/- 2.663e-09

# %%
diff20_0_60 = (J_0_60c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_0_60)) + "% from control")

diff20_60_120 = (J_60_120c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_60_120)) + "% from control")


diff20_120_180 = (J_120_180c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_120_180)) + "% from control")


diff20_180_240 = (J_180_240c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_180_240)) + "% from control")


diff20_240_300 = (J_240_300c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_240_300)) + "% from control")


diff20_300_360 = (J_300_360c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_300_360)) + "% from control")
# Out:
# 0.626% from control
# 0.010% from control
# 0.392% from control
# 0.425% from control
# 0.010% from control
# 0.057% from control

# %% [markdown]
# The same exercise was performed as above for testing the sensitivity of the model to the pebble burnup locations (the model still uses a 1/6 symmetry).  The locations of the pebbles stayed the same, but had different burnups assigned to them, as follows:
#
# Original (Run 1): <br>
#
# Positions "0":  Burnup 0 <br>
# Positions "1":  Burnup 1 <br>
# Positions "2":  Burnup 2 <br>
# Positions "3":  Burnup 3 <br>
# Positions "4":  Burnup 4 <br>
# Positions "5":  Burnup 5 <br>
# Positions "6":  Burnup 6 <br>
#
# This model is identical to the 0-60 slice run described above.  To change the level of the burnup locations, subsequent runs had the pebble compositions re-assigned as follows:
#
# Run 2: <br>
#
# Positions "0":  Burnup 6 <br>
# Positions "1":  Burnup 0 <br>
# Positions "2":  Burnup 1 <br>
# Positions "3":  Burnup 2 <br>
# Positions "4":  Burnup 3 <br>
# Positions "5":  Burnup 4 <br>
# Positions "6":  Burnup 5 <br>
#
# Run 3: <br>
#
# Positions "0":  Burnup 5 <br>
# Positions "1":  Burnup 6 <br>
# Positions "2":  Burnup 0 <br>
# Positions "3":  Burnup 1 <br>
# Positions "4":  Burnup 2 <br>
# Positions "5":  Burnup 3 <br>
# Positions "6":  Burnup 4 <br>
#
# Run 4: <br>
#
# Positions "0":  Burnup 4 <br>
# Positions "1":  Burnup 5 <br>
# Positions "2":  Burnup 6 <br>
# Positions "3":  Burnup 0 <br>
# Positions "4":  Burnup 1 <br>
# Positions "5":  Burnup 2 <br>
# Positions "6":  Burnup 3 <br>
#
# Run 5: <br>
#
# Positions "0":  Burnup 3 <br>
# Positions "1":  Burnup 4 <br>
# Positions "2":  Burnup 5 <br>
# Positions "3":  Burnup 6 <br>
# Positions "4":  Burnup 0 <br>
# Positions "5":  Burnup 1 <br>
# Positions "6":  Burnup 2 <br>
#
# Run 6: <br>
#
# Positions "0":  Burnup 2 <br>
# Positions "1":  Burnup 3 <br>
# Positions "2":  Burnup 4 <br>
# Positions "3":  Burnup 5 <br>
# Positions "4":  Burnup 6 <br>
# Positions "5":  Burnup 0 <br>
# Positions "6":  Burnup 1 <br>
#
# Run 7: <br>
#
# Positions "0":  Burnup 1 <br>
# Positions "1":  Burnup 2 <br>
# Positions "2":  Burnup 3 <br>
# Positions "3":  Burnup 4 <br>
# Positions "4":  Burnup 5 <br>
# Positions "5":  Burnup 6 <br>
# Positions "6":  Burnup 0 <br>
#
# The detector size didn't change from the previous runs, so the conversion to $[\frac{n}{cm^2s}]$ is simple.

# %%
J_0_60 = 3.002 * 10**17
delJ_0_60 = 0.00147
J_0_60c = J_0_60/sa20det
delJ_0_60c = (delJ_0_60/sa20det)*J_0_60c
print("Run 1: " + "{:.3e}".format(J_0_60c) + " +/- " + "{:.3e}".format(delJ_0_60c))
print()

J_r2 = 2.98957E+17
delJ_r2 = 0.00147
J_r2c = J_r2/sa20det
delJ_r2c = (delJ_r2/sa20det)*J_r2c
print("Run 2: " + "{:.3e}".format(J_r2c) + " +/- " + "{:.3e}".format(delJ_r2c))
print()

J_r3 = 2.99211E+17
delJ_r3 = 0.00137
J_r3c = J_r3/sa20det
delJ_r3c = (delJ_r3/sa20det)*J_r3c
print("Run 3: " + "{:.3e}".format(J_r3c) + " +/- " + "{:.3e}".format(delJ_r3c))
print()

J_r4 = 2.98905E+17
delJ_r4 = 0.00144
J_r4c = J_r4/sa20det
delJ_r4c = (delJ_r4/sa20det)*J_r4c
print("Run 4: " + "{:.3e}".format(J_r4c) + " +/- " + "{:.3e}".format(delJ_r4c))
print()

J_r5 = 2.98293E+17
delJ_r5 = 0.00159 
J_r5c = J_r5/sa20det
delJ_r5c = (delJ_r5/sa20det)*J_r5c
print("Run 5: " + "{:.3e}".format(J_r5c) + " +/- " + "{:.3e}".format(delJ_r5c))
print()

J_r6 = 2.99312E+17
delJ_r6 = 0.00143
J_r6c = J_r6/sa20det
delJ_r6c = (delJ_r6/sa20det)*J_r6c
print("Run 6: " + "{:.3e}".format(J_r6c) + " +/- " + "{:.3e}".format(delJ_r6c))
print()

J_r7 = 2.99009E+17
delJ_r7 = 0.00131
J_r7c = J_r7/sa20det
delJ_r7c = (delJ_r7/sa20det)*J_r7c
print("Run 7: " + "{:.3e}".format(J_r7c) + " +/- " + "{:.3e}".format(delJ_r7c))
print()
# Out:
# Run 1: 5.921e+11 +/- 2.900e-09
#
# Run 2: 5.897e+11 +/- 1.710e+03
#
# Run 3: 5.902e+11 +/- 1.595e+03
#
# Run 4: 5.896e+11 +/- 1.675e+03
#
# Run 5: 5.884e+11 +/- 1.845e+03
#
# Run 6: 5.904e+11 +/- 1.665e+03
#
# Run 7: 5.898e+11 +/- 1.524e+03

# %% [markdown]
# These results can be compared to the control, as before, using the relative difference...

# %%
diff20_0_60 = (J_0_60c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_0_60)) + "% from control")

diff20_r2 = (J_r2c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_r2)) + "% from control")


diff20_r3 = (J_r3c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_r3)) + "% from control")


diff20_r4 = (J_r4c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_r4)) + "% from control")


diff20_r5 = (J_r5c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_r5)) + "% from control")


diff20_r6 = (J_r6c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_r6)) + "% from control")

diff20_r7 = (J_r7c - J_20c)/(J_20c)*100 # in %
print("{:.3f}".format(abs(diff20_r7)) + "% from control")
# Out:
# 0.626% from control
# 0.210% from control
# 0.295% from control
# 0.192% from control
# 0.013% from control
# 0.329% from control
# 0.227% from control

# %% [markdown]
# The reflector thickness is chosen such that the outward surface current is less than or equal to the outward current of the 200MWth design.  The outward current for this design can be, as above, found by dividing the surface current given in the Serpent output, in $[\frac{n}{s}]$, by the surface area of the detector.  Thus, the "target" current is:

# %%
r200det = 215 #detector radius, cm
h200det = 2*574 #detector height, cm

sa200det = (2*r200det*np.pi*h200det)+ 2*(np.pi*r200det**2) #detector surface area, cm

J_200 = 1.35352 * 10**18
delJ_200 = 0.00130
J_200c = J_200/sa200det
delJ_200c = delJ_200/sa200det
print("200MWth full core: " + "{:.3e}".format(J_200c) + " +/- " + "{:.3e}".format(delJ_200c))
# Out:
# 200MWth full core: 7.351e+11 +/- 7.060e-10

# %% [markdown]
# The relative difference is simply
# $$ \frac{J^+_{200} - J^+_{20}}{J^+_{200}} $$

# %%
diff_0_60 = (J_0_60c - J_200c)/(J_200c)*100 # in %
if diff_0_60 < 0:
    print("{:.3f}".format(abs(diff_0_60)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_0_60)) + "% increase")


diff_60_120 = (J_60_120c - J_200c)/(J_200c)*100 # in %
if diff_60_120 < 0:
    print("{:.3f}".format(abs(diff_60_120)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_60_120)) + "% increase")


diff_120_180 = (J_120_180c - J_200c)/(J_200c)*100 # in %
if diff_120_180 < 0:
    print("{:.3f}".format(abs(diff_120_180)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_120_180)) + "% increase")


diff_180_240 = (J_180_240c - J_200c)/(J_200c)*100 # in %
if diff_180_240 < 0:
    print("{:.3f}".format(abs(diff_180_240)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_180_240)) + "% increase")


diff_240_300 = (J_240_300c - J_200c)/(J_200c)*100 # in %
if diff_240_300 < 0:
    print("{:.3f}".format(abs(diff_240_300)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_240_300)) + "% increase")


diff_300_360 = (J_300_360c - J_200c)/(J_200c)*100 # in %
if diff_300_360 < 0:
    print("{:.3f}".format(abs(diff_300_360)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_300_360)) + "% increase")
# Out:
# 19.449% decrease
# 19.959% decrease
# 19.637% decrease
# 19.610% decrease
# 19.959% decrease
# 19.905% decrease

# %% [markdown]
# The same can be calculated for the burnup-shuffling test:

# %%
diff_0_60 = (J_0_60c - J_200c)/(J_200c)*100 # in %
if diff_0_60 < 0:
    print("{:.3f}".format(abs(diff_0_60)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_0_60)) + "% increase")


diff_r2 = (J_r2c - J_200c)/(J_200c)*100 # in %
if diff_r2 < 0:
    print("{:.3f}".format(abs(diff_r2)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_r2)) + "% increase")


diff_r3 = (J_r3c - J_200c)/(J_200c)*100 # in %
if diff_r3 < 0:
    print("{:.3f}".format(abs(diff_r3)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_r3)) + "% increase")


diff_r4 = (J_r4c - J_200c)/(J_200c)*100 # in %
if diff_r4 < 0:
    print("{:.3f}".format(abs(diff_r4)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_r4)) + "% increase")


diff_r5 = (J_r5c - J_200c)/(J_200c)*100 # in %
if diff_r5 < 0:
    print("{:.3f}".format(abs(diff_r5)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_r5)) + "% increase")


diff_r6 = (J_r6c - J_200c)/(J_200c)*100 # in %
if diff_r6< 0:
    print("{:.3f}".format(abs(diff_r6)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_r6)) + "% increase")
    
diff_r7 = (J_r7c - J_200c)/(J_200c)*100 # in %
if diff_r7 < 0:
    print("{:.3f}".format(abs(diff_r7)) + "% decrease")
else:
    print("{:.3f}".format(abs(diff_r7)) + "% increase")
# Out:
# 19.449% decrease
# 19.637% decrease
# 19.905% decrease
# 19.664% decrease
# 19.342% decrease
# 19.207% decrease
# 19.073% decrease

# %% [markdown]
# How much damage is ~6.0e11 $\frac{n}{cm^2s}$?  Using the following example from Light Water Reactor Materials, page 555 by Olander to make an estimate,
# ![olander-555](olander-pg555.jpg)
# With 6.0e11 $\frac{n}{cm^2s}$ as the incoming neutron current and 20 years as the lifetime, we have

# %%
etp = 0.069
sigS = 3*10**(-24)
Ed = 4

flux = 6.0e+11

dpas = flux*(sigS/(Ed*25))*etp*10**6

print("{:.2e}".format(dpas) + " dpa per second")
# Out:
# 1.24e-09 dpa per second

# %%
time = 60*60*24*365*20

dpa = time*dpas


print("{:.2e}".format(dpa) + " total dpa in lifetime")
# Out:
# 7.83e-01 total dpa in lifetime

# %%
fluence = flux*time
print("{:.2e}".format(fluence) + " total fluence in lifetime")
# Out:
# 3.78e+20 total fluence in lifetime

# %%
rdet = [149,150,151, 152, 153, 154, 155, 156, 157, 158, 159, 160,
        161, 162, 163, 164, 165, 166, 167, 168, 169,  174] #detector radius, cm, h = 2r

jout = [3.81909E+17,3.69988E+17,3.69706E+17,3.63749E+17,3.56906E+17,3.51244E+17,
        3.44891E+17,3.40773E+17,3.34593E+17,3.30305E+17,3.24404E+17,3.19477E+17,
        3.14463E+17,3.09080E+17,3.04416E+17,2.99788E+17,2.94288E+17,2.91140E+17,
        2.85709E+17,2.82150E+17,2.77906E+17,2.57451E+17]

delj = [.00150,0.00145,0.00135,0.00130,0.00136,0.00124,0.00129,0.00133,
        0.00135,0.00152,0.00125,0.00143,0.00152,0.00140,0.00138,0.00139,
        0.00136,0.00156,0.00128,0.00132,0.00152,0.00143]

imp_keff = [1.01545,1.01916,1.01962,1.02139,1.02344,1.02535,1.02772,
            1.02815,1.03027,1.03107,1.03313,1.03501,1.03587,1.03761,
            1.03922,1.03988,1.04224,1.04183,1.04401,1.04432,1.04548,1.04976]

delimp_keff = [0.00038,0.00039,0.00039,0.00037,0.00037,0.00036,0.00034,
             0.00036,0.00039,0.00037,0.00034,0.00038,0.00040,0.00037,
             0.00035,0.00034,0.00037,0.00038,0.00032,0.00036,0.00035,0.00035]

joutc = []
deljc = []

for i, r in enumerate(rdet):
    sadet = (2*r*np.pi*2*r)+ 2*(np.pi*r**2)
    joutc.append(jout[i]/(sadet))
    deljc.append(delj[i]/sadet)

for i, v in enumerate(joutc):
    print("At Reflector thickness " + "{:d}".format(rdet[i]-89) + " cm, Jout is " +  
          "{:.3e}".format(v) + " +/- " + "{:.3e}".format(deljc[i])  )
    print()
# Out:
# At Reflector thickness 60 cm, Jout is 9.126e+11 +/- 3.584e-09
#
# At Reflector thickness 61 cm, Jout is 8.724e+11 +/- 3.419e-09
#
# At Reflector thickness 62 cm, Jout is 8.602e+11 +/- 3.141e-09
#
# At Reflector thickness 63 cm, Jout is 8.352e+11 +/- 2.985e-09
#
# At Reflector thickness 64 cm, Jout is 8.089e+11 +/- 3.082e-09
#
# At Reflector thickness 65 cm, Jout is 7.857e+11 +/- 2.774e-09
#
# At Reflector thickness 66 cm, Jout is 7.616e+11 +/- 2.849e-09
#
# At Reflector thickness 67 cm, Jout is 7.429e+11 +/- 2.899e-09
#
# At Reflector thickness 68 cm, Jout is 7.201e+11 +/- 2.906e-09
#
# At Reflector thickness 69 cm, Jout is 7.019e+11 +/- 3.230e-09
#
# At Reflector thickness 70 cm, Jout is 6.808e+11 +/- 2.623e-09
#
# At Reflector thickness 71 cm, Jout is 6.621e+11 +/- 2.963e-09
#
# At Reflector thickness 72 cm, Jout is 6.436e+11 +/- 3.111e-09
#
# At Reflector thickness 73 cm, Jout is 6.248e+11 +/- 2.830e-09
#
# At Reflector thickness 74 cm, Jout is 6.078e+11 +/- 2.756e-09
#
# ...

# %%
plt.plot(rdet,joutc)
plt.plot(rdet, J_200c*np.ones(len(rdet)))
plt.title("$J^+$ vs Reflector Thickness")
plt.xlabel("Reflector Thickness [cm]")
plt.ylabel("$J^+$ [n/cm^2-s]")
plt.legend(["$J^+$: Sangamon1","$J^+$ at Outer Bound: Sangamon0"])

# %%
plt.plot(rdet,imp_keff)
plt.plot(rdet,np.ones(len(rdet)))
plt.title("Implicit $k_{eff}$ vs Reflector Thickness")
plt.xlabel("Reflector Thickness [cm]")
plt.ylabel("$k_{eff}$")
# Out:
# Text(0, 0.5, '$k_{eff}$')

# %%
control = cv2.imread("htgr-20/full-core-control/htgr-20-full-core-control-mesh1.png")
slice1 = cv2.imread("htgr-20/slice-0-60/htgr-20-full-core-0-60-mesh1.png")

# %%
diff = cv2.subtract(control,slice1)

# %%
cv2.imwrite('htgr-diff.png',diff)
# Out:
# True

# %%
mass0 = cv2.imread("htgr-20/pebb-mass/htgr-20-full-core-mass0.inp_mesh1.png")
mass6 = cv2.imread("htgr-20/pebb-mass/htgr-20-full-core-mass6.inp_mesh1.png")

diff = cv2.subtract(mass0,mass6)

# %%
cv2.imwrite('pebb-mass-0-6-diff.png',diff)
# Out:
# True

# %%
xy_bins = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m",skiprows = 5456589,
                      nrows = 1650 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, delim_whitespace= True, usecols = [1])

# %%
rad_xy_therm = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m", skiprows = 1369527, 
                           nrows = 1650,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [10,11])

# %%
rad_xy_fast = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m", skiprows = 4092027, 
                          nrows = 1650,index_col = False, header = None, engine = 'python',
                          skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                          usecols = [10,11])

# %%
therm_xy = xy_bins.merge(rad_xy_therm, left_index = True, right_index = True)

fast_xy = xy_bins.merge(rad_xy_fast, left_index = True, right_index = True)

# %%
therm_err = []

for i, err in enumerate(therm_xy[11]):
    therm_err.append(err*therm_xy[10][i])
    
plt.errorbar(therm_xy[1],therm_xy[10],yerr= therm_err,ecolor='black',errorevery = 10,alpha = 0.75)
plt.title("Thermal Flux: Homogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('Position [cm]')
# Out:
# Text(0.5, 0, 'Position [cm]')

# %%
bins1, centers = pd.cut(therm_xy[1],bins=165,include_lowest = True, retbins=True)

# %%
bins = []
for b in bins1:
    if b in bins:
        pass
    else:
        bins.append(b)

# %%
#rebinning...
rb_therm = np.zeros(len(centers))

rb_temp = np.zeros(len(centers))
rb_count = np.zeros(len(centers))

for i, v in enumerate(therm_xy[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_temp[j] += therm_xy[10][i]
            rb_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rb_temp):
    if rb_count[i] > 0:
        rb_therm[i] = v/rb_count[i]
        
    else:
        pass
    
    
rb_err_temp = np.zeros(len(centers))
rb_err_count = np.zeros(len(centers))
for i, v in enumerate(therm_xy[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_err_temp[j] += therm_xy[10][i]*therm_xy[11][i]
            rb_err_count[j] += 1
            
        else:
            pass
rb_err_therm = np.zeros(len(centers))
for i, v in enumerate(rb_err_temp):
    if rb_err_count[i] > 0:
        rb_err_therm[i] += v/rb_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centers,rb_therm,yerr=rb_err_therm,ecolor='black', barsabove = True,errorevery = 3)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Thermal Flux: Homogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('X Position [cm]')
plt.savefig('therm_flux_homog.png',dpi = 600)

# %%
#rebinning...
rb_fast = np.zeros(len(centers))

rb_temp = np.zeros(len(centers))
rb_count = np.zeros(len(centers))

for i, v in enumerate(fast_xy[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_temp[j] += fast_xy[10][i]
            rb_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rb_temp):
    if rb_count[i] > 0:
        rb_fast[i] = v/rb_count[i]
        
    else:
        pass
    
    
rb_err_temp = np.zeros(len(centers))
rb_err_count = np.zeros(len(centers))
for i, v in enumerate(fast_xy[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_err_temp[j] += fast_xy[10][i]*fast_xy[11][i]
            rb_err_count[j] += 1
            
        else:
            pass
rb_err_fast = np.zeros(len(centers))
for i, v in enumerate(rb_err_temp):
    if rb_err_count[i] > 0:
        rb_err_fast[i] += v/rb_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centers,rb_fast,yerr=rb_err_fast,ecolor='black', barsabove = True,errorevery = 3)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Fast Flux: Homogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('X Position [cm]')
plt.savefig('fast_flux_homog.png',dpi = 600)

# %%
# axial next, here

z_bins = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m", skiprows = 6624, 
                           nrows = 3300,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [1])

therm_z = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m", skiprows = 7, 
                           nrows = 3300,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [10,11])

fast_z = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m", skiprows = 3307, 
                           nrows = 3300,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [10,11])

# %%
bins1, centerz = pd.cut(z_bins[1],bins=330,include_lowest = True, retbins=True)

bins = []
for b in bins1:
    if b in bins:
        pass
    else:
        bins.append(b)
        
zbin_vol = np.pi*(165**2)*(330/3300)
xbin_vol = (330/1650)*(330/1650)*330
bin_vol_ratio = xbin_vol/zbin_vol

# %%
#rebinning...
rbz_therm = np.zeros(len(centerz))

rbz_temp = np.zeros(len(centerz))
rbz_count = np.zeros(len(centerz))

for i, v in enumerate(z_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_temp[j] += therm_z[10][i]*bin_vol_ratio
            rbz_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rbz_temp):
    if rbz_count[i] > 0:
        rbz_therm[i] = v/rbz_count[i]
        
    else:
        pass
    
    
rbz_err_temp = np.zeros(len(centerz))
rbz_err_count = np.zeros(len(centerz))
for i, v in enumerate(z_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_err_temp[j] += therm_z[10][i]*therm_z[11][i]*bin_vol_ratio
            rbz_err_count[j] += 1
            
        else:
            pass

rbz_err_therm = np.zeros(len(centerz))
for i, v in enumerate(rbz_err_temp):
    if rbz_err_count[i] > 0:
        rbz_err_therm[i] += v/rbz_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centerz,rbz_therm,yerr=rbz_err_therm,ecolor='black', barsabove = True,errorevery = 3, linewidth = 0.6)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Thermal Flux: Homogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('Z Position [cm]')
plt.savefig('therm_flux_homog_z.png',dpi = 600)

# %%
#rebinning...
rbz_fast = np.zeros(len(centerz))

rbz_temp = np.zeros(len(centerz))
rbz_count = np.zeros(len(centerz))

for i, v in enumerate(z_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_temp[j] += fast_z[10][i]*bin_vol_ratio
            rbz_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rbz_temp):
    if rbz_count[i] > 0:
        rbz_fast[i] = v/rbz_count[i]
        
    else:
        pass
    
    
rbz_err_temp = np.zeros(len(centerz))
rbz_err_count = np.zeros(len(centerz))
for i, v in enumerate(z_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_err_temp[j] += fast_z[10][i]*fast_z[11][i]*bin_vol_ratio
            rbz_err_count[j] += 1
            
        else:
            pass

rbz_err_fast = np.zeros(len(centerz))
for i, v in enumerate(rbz_err_temp):
    if rbz_err_count[i] > 0:
        rbz_err_fast[i] += v/rbz_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centerz,rbz_fast,yerr=rbz_err_fast,ecolor='black', barsabove = True,errorevery = 3, linewidth = 0.6)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Fast Flux: Homogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('Z Position [cm]')
plt.savefig('fast_flux_homog_z.png',dpi = 600)

# %%
therm_xy_plane = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m",skiprows = 9927, nrows = 2722500,index_col = False, header = None, engine = 'python',skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, usecols = [8,9,10,11])

# %%
temp_plane = therm_xy_plane.drop(labels = 9, axis = 1)

# %%
therm_phi_matrix = []
for i in range(1650):
    temp = []
    for j in range(1650):
        key = i*1650 + j
        temp.append(temp_plane[temp_plane.loc[:,8] == i + 1].loc[key,10])
    print("Loop " + str(i)) 
    therm_phi_matrix.append(temp)
# Out:
# Loop 0
# Loop 1
# Loop 2
# Loop 3
# Loop 4
# Loop 5
# Loop 6
# Loop 7
# Loop 8
# Loop 9
# Loop 10
# Loop 11
# Loop 12
# Loop 13
# Loop 14
# Loop 15
# Loop 16
# Loop 17
# Loop 18
# Loop 19
# Loop 20
# Loop 21
# Loop 22
# Loop 23
# Loop 24
# Loop 25
# Loop 26
# Loop 27
# Loop 28
# Loop 29
# Loop 30
# Loop 31
# Loop 32
# Loop 33
# Loop 34
# Loop 35
# Loop 36
# Loop 37
# Loop 38
# Loop 39
# Loop 40
# Loop 41
# Loop 42
# Loop 43
# Loop 44
# Loop 45
# Loop 46
# Loop 47
# Loop 48
# Loop 49
# Loop 50
# Loop 51
# Loop 52
# Loop 53
# Loop 54
# Loop 55
# Loop 56
# Loop 57
# Loop 58
# Loop 59
# Loop 60
# Loop 61
# Loop 62
# Loop 63
# Loop 64
# Loop 65
# Loop 66
# Loop 67
# Loop 68
# Loop 69
# Loop 70
# Loop 71
# Loop 72
# Loop 73
# Loop 74
# Loop 75
# Loop 76
# Loop 77
# Loop 78
# Loop 79
# Loop 80
# Loop 81
# Loop 82
# Loop 83
# Loop 84
# Loop 85
# Loop 86
# Loop 87
# Loop 88
# Loop 89
# Loop 90
# Loop 91
# Loop 92
# Loop 93
# Loop 94
# Loop 95
# Loop 96
# Loop 97
# Loop 98
# Loop 99
# ...

# %%
xy_ticks = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m",skiprows = 5456589, 
                      nrows = 1650 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, delim_whitespace= True, usecols = [1])

fig, ax = plt.subplots()
plt.pcolormesh(xy_ticks.transpose(),xy_ticks,therm_phi_matrix,snap = True,shading = 'auto',cmap = 'magma')
plt.colorbar()
plt.title('Thermal Flux')
plt.xlabel("Position [cm]")
plt.ylabel("Position [cm]")
ax.set_aspect('equal')
plt.savefig('therm_xy_plane_homog.png',dpi = 600)

# %%
fast_xy_plane = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m",skiprows = 2732427, nrows = 2722500,index_col = False, header = None, engine = 'python',skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, usecols = [8,9,10,11])

temp_plane = fast_xy_plane.drop(labels = 9, axis = 1)

fast_phi_matrix = []
for i in range(1650):
    temp = []
    for j in range(1650):
        key = i*1650 + j
        temp.append(temp_plane[temp_plane.loc[:,8] == i + 1].loc[key,10])
    print("Loop " + str(i)) 
    fast_phi_matrix.append(temp)
# Out:
# Loop 0
# Loop 1
# Loop 2
# Loop 3
# Loop 4
# Loop 5
# Loop 6
# Loop 7
# Loop 8
# Loop 9
# Loop 10
# Loop 11
# Loop 12
# Loop 13
# Loop 14
# Loop 15
# Loop 16
# Loop 17
# Loop 18
# Loop 19
# Loop 20
# Loop 21
# Loop 22
# Loop 23
# Loop 24
# Loop 25
# Loop 26
# Loop 27
# Loop 28
# Loop 29
# Loop 30
# Loop 31
# Loop 32
# Loop 33
# Loop 34
# Loop 35
# Loop 36
# Loop 37
# Loop 38
# Loop 39
# Loop 40
# Loop 41
# Loop 42
# Loop 43
# Loop 44
# Loop 45
# Loop 46
# Loop 47
# Loop 48
# Loop 49
# Loop 50
# Loop 51
# Loop 52
# Loop 53
# Loop 54
# Loop 55
# Loop 56
# Loop 57
# Loop 58
# Loop 59
# Loop 60
# Loop 61
# Loop 62
# Loop 63
# Loop 64
# Loop 65
# Loop 66
# Loop 67
# Loop 68
# Loop 69
# Loop 70
# Loop 71
# Loop 72
# Loop 73
# Loop 74
# Loop 75
# Loop 76
# Loop 77
# Loop 78
# Loop 79
# Loop 80
# Loop 81
# Loop 82
# Loop 83
# Loop 84
# Loop 85
# Loop 86
# Loop 87
# Loop 88
# Loop 89
# Loop 90
# Loop 91
# Loop 92
# Loop 93
# Loop 94
# Loop 95
# Loop 96
# Loop 97
# Loop 98
# Loop 99
# ...

# %%
xy_ticks = pd.read_csv("htgr-20/htgr-20-full-core-rad-ax-flux.inp_det0.m",skiprows = 5456589, 
                      nrows = 1650 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, delim_whitespace= True, usecols = [1])

fig, ax = plt.subplots()
plt.pcolormesh(xy_ticks.transpose(),xy_ticks,fast_phi_matrix,snap = True,shading = 'auto',cmap = 'magma')
plt.colorbar()
plt.title('Fast Flux')
plt.xlabel("Position [cm]")
plt.ylabel("Position [cm]")
ax.set_aspect('equal')
plt.savefig('fast_xy_plane_homog.png',dpi = 600)

# %%
e_ticks = pd.read_csv("htgr-20/htgr-20-spectrum-fine.inp_det0.m",skiprows = 321, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, usecols = [1])

# %%
core_spec = pd.read_csv("htgr-20/htgr-20-spectrum-fine.inp_det0.m",skiprows = 2, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, usecols = [10,11])

# %%
fresh_spec = pd.read_csv("htgr-20/htgr-20-spectrum-fine.inp_det0.m",skiprows = 639, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, usecols = [10,11])

# %%
six_spec = pd.read_csv("htgr-20/htgr-20-spectrum-fine.inp_det0.m",skiprows = 1276, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, usecols = [10,11])

# %%
cool_spec = pd.read_csv("htgr-20/htgr-20-spectrum-fine.inp_det0.m",skiprows = 1913, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, usecols = [10,11])

# %%
reflec_spec = pd.read_csv("htgr-20/htgr-20-spectrum-fine.inp_det0.m",skiprows = 2550, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, usecols = [10,11])

# %%
core_err = []

for i,v in enumerate(core_spec[11]):
    core_err.append(v*core_spec[10][i])

plt.errorbar(e_ticks[1],core_spec[10],yerr= core_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Homogenized Core")
plt.xlabel('Energy [MeV]')
plt.ylabel( r'Neutron Flux Per Unit Lethargy $[\frac{n}{cm^2s}]$')
plt.savefig('core_spec_homog.png',dpi = 600)

# %%
fresh_err = []

for i,v in enumerate(fresh_spec[11]):
    fresh_err.append(v*fresh_spec[10][i])

plt.errorbar(e_ticks[1],fresh_spec[10],yerr= fresh_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Homogenized Fresh Pebble")
plt.xlabel('Energy [MeV]')
plt.ylabel( r'Neutron Flux Per Unit Lethargy $[\frac{n}{cm^2s}]$')
plt.savefig('fresh_spec_homog.png',dpi = 600)

# %%
six_err = []

for i,v in enumerate(six_spec[11]):
    six_err.append(v*six_spec[10][i])

plt.errorbar(e_ticks[1],six_spec[10],yerr= six_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Homogenized 6-Pass Pebble")
plt.xlabel('Energy [MeV]')
plt.ylabel( r'Neutron Flux Per Unit Lethargy $[\frac{n}{cm^2s}]$')
plt.savefig('6_spec_homog.png',dpi = 600)

# %%
cool_err = []

for i,v in enumerate(cool_spec[11]):
    cool_err.append(v*cool_spec[10][i])

plt.errorbar(e_ticks[1],cool_spec[10],yerr= cool_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Homogenized Coolant")
plt.xlabel('Energy [MeV]')
plt.ylabel( r'Neutron Flux Per Unit Lethargy $[\frac{n}{cm^2s}]$')
plt.savefig('cool_spec_homog.png',dpi = 600)

# %%
reflec_err = []

for i,v in enumerate(reflec_spec[11]):
    reflec_err.append(v*reflec_spec[10][i])

plt.errorbar(e_ticks[1],reflec_spec[10],yerr= reflec_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Homogenized Reflector")
plt.xlabel('Energy [MeV]')
plt.ylabel( r'Neutron Flux Per Unit Lethargy $[\frac{n}{cm^2s}]$')
plt.savefig('reflect_spec_homog.png',dpi = 600)

# %% [markdown]
# ### Now for heterogenized plots

# %%
xy_het_bins = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5445016, 
                          nrows = 1650 ,index_col = False, header = None, engine = 'python',
                          skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                          usecols = [1])

therm_het_xy = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m", skiprows = 1359607, 
                           nrows = 1650,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [10,11])

fast_het_xy = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m", skiprows = 4082107, 
                           nrows = 1650,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [10,11])

# %%
bins1, centers = pd.cut(xy_het_bins[1],bins=165,include_lowest = True, retbins=True)

bins = []
for b in bins1:
    if b in bins:
        pass
    else:
        bins.append(b)

# %%
#rebinning...
rb_het_therm = np.zeros(len(centers))

rb_temp = np.zeros(len(centers))
rb_count = np.zeros(len(centers))

for i, v in enumerate(xy_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_temp[j] += therm_het_xy[10][i]
            rb_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rb_temp):
    if rb_count[i] > 0:
        rb_het_therm[i] = v/rb_count[i]
        
    else:
        pass
    
    
rb_err_temp = np.zeros(len(centers))
rb_err_count = np.zeros(len(centers))
for i, v in enumerate(xy_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_err_temp[j] += therm_het_xy[10][i]*therm_het_xy[11][i]
            rb_err_count[j] += 1
            
        else:
            pass
rb_het_err_therm = np.zeros(len(centers))
for i, v in enumerate(rb_err_temp):
    if rb_err_count[i] > 0:
        rb_het_err_therm[i] += v/rb_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centers,rb_het_therm,yerr=rb_het_err_therm,ecolor='black', barsabove = True,errorevery = 3, linewidth = 0.6)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Thermal Flux: Heterogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('X Position [cm]')
plt.savefig('therm_flux_het.png',dpi = 600)

# %%
#rebinning...
rb_het_fast = np.zeros(len(centers))

rb_temp = np.zeros(len(centers))
rb_count = np.zeros(len(centers))

for i, v in enumerate(xy_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_temp[j] += fast_het_xy[10][i]
            rb_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rb_temp):
    if rb_count[i] > 0:
        rb_het_fast[i] = v/rb_count[i]
        
    else:
        pass
    
    
rb_err_temp = np.zeros(len(centers))
rb_err_count = np.zeros(len(centers))
for i, v in enumerate(xy_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rb_err_temp[j] += fast_het_xy[10][i]*fast_het_xy[11][i]
            rb_err_count[j] += 1
            
        else:
            pass
rb_het_err_fast = np.zeros(len(centers))
for i, v in enumerate(rb_err_temp):
    if rb_err_count[i] > 0:
        rb_het_err_fast[i] += v/rb_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centers,rb_het_fast,yerr=rb_het_err_fast,ecolor='black', barsabove = True,errorevery = 3, linewidth = 0.6)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Fast Flux: Heterogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('X Position [cm]')
plt.savefig('fast_flux_het.png',dpi = 600)

# %%
z_het_bins = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m", skiprows = 5454943, 
                           nrows = 3300,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [1])

therm_het_z = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m", skiprows = 5448326, 
                           nrows = 3300,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [10,11])

fast_het_z = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m", skiprows = 5451626, 
                           nrows = 3300,index_col = False, header = None, engine = 'python',
                           skip_blank_lines = True, error_bad_lines = False, delim_whitespace= True, 
                           usecols = [10,11])

# %%
bins1, centerz = pd.cut(z_het_bins[1],bins=330,include_lowest = True, retbins=True)

bins = []
for b in bins1:
    if b in bins:
        pass
    else:
        bins.append(b)

# %%
#rebinning...
rbz_het_therm = np.zeros(len(centerz))

rbz_temp = np.zeros(len(centerz))
rbz_count = np.zeros(len(centerz))

for i, v in enumerate(z_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_temp[j] += therm_het_z[10][i]*bin_vol_ratio
            rbz_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rbz_temp):
    if rbz_count[i] > 0:
        rbz_het_therm[i] = v/rbz_count[i]
        
    else:
        pass
    
    
rbz_err_temp = np.zeros(len(centerz))
rbz_err_count = np.zeros(len(centerz))
for i, v in enumerate(z_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_err_temp[j] += therm_het_z[10][i]*therm_het_z[11][i]*bin_vol_ratio
            rbz_err_count[j] += 1
            
        else:
            pass

rbz_het_err_therm = np.zeros(len(centerz))
for i, v in enumerate(rbz_err_temp):
    if rbz_err_count[i] > 0:
        rbz_het_err_therm[i] += v/rbz_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centerz,rbz_het_therm,yerr=rbz_het_err_therm,ecolor='black', barsabove = True,errorevery = 3, linewidth = 0.6)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Thermal Flux: Heterogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('Z Position [cm]')
plt.savefig('therm_flux_het_z.png',dpi = 600)

# %%
#rebinning...
rbz_het_fast = np.zeros(len(centerz))

rbz_temp = np.zeros(len(centerz))
rbz_count = np.zeros(len(centerz))

for i, v in enumerate(z_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_temp[j] += fast_het_z[10][i]*bin_vol_ratio
            rbz_count[j] += 1
            
        else:
            pass

        
for i, v in enumerate(rbz_temp):
    if rbz_count[i] > 0:
        rbz_het_fast[i] = v/rbz_count[i]
        
    else:
        pass
    
    
rbz_err_temp = np.zeros(len(centerz))
rbz_err_count = np.zeros(len(centerz))
for i, v in enumerate(z_het_bins[1]):
    
    for j, b in enumerate(bins):
        if v in b:
            rbz_err_temp[j] += fast_het_z[10][i]*fast_het_z[11][i]*bin_vol_ratio
            rbz_err_count[j] += 1
            
        else:
            pass

rbz_het_err_fast = np.zeros(len(centerz))
for i, v in enumerate(rbz_err_temp):
    if rbz_err_count[i] > 0:
        rbz_het_err_fast[i] += v/rbz_err_count[i]
        
    else:
        pass

# %%
plt.errorbar(centerz,rbz_het_fast,yerr=rbz_het_err_fast,ecolor='black', barsabove = True,errorevery = 3, linewidth = 0.6)
plt.yscale('log')
plt.xlim(xmin = -165, xmax = 165)
plt.title("Fast Flux: Heterogenized Pebbles")
plt.ylabel(r'$\phi [\frac{n}{cm^2s}]$')
plt.xlabel('Z Position [cm]')
plt.savefig('fast_flux_het_z.png',dpi = 600)

# %%
therm_het_xy_plane = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 7,
                             nrows = 2722500,index_col = False, header = None, engine = 'python',
                             skip_blank_lines = True, error_bad_lines = False, 
                             delim_whitespace= True, usecols = [8,10,11])

# %%
therm_het_phi_matrix = []
for i in range(1650):
    temp = []
    for j in range(1650):
        key = i*1650 + j
        temp.append(therm_het_xy_plane[therm_het_xy_plane.loc[:,8] == i + 1].loc[key,10])
    print("Loop " + str(i)) 
    therm_het_phi_matrix.append(temp)
# Out:
# Loop 0
# Loop 1
# Loop 2
# Loop 3
# Loop 4
# Loop 5
# Loop 6
# Loop 7
# Loop 8
# Loop 9
# Loop 10
# Loop 11
# Loop 12
# Loop 13
# Loop 14
# Loop 15
# Loop 16
# Loop 17
# Loop 18
# Loop 19
# Loop 20
# Loop 21
# Loop 22
# Loop 23
# Loop 24
# Loop 25
# Loop 26
# Loop 27
# Loop 28
# Loop 29
# Loop 30
# Loop 31
# Loop 32
# Loop 33
# Loop 34
# Loop 35
# Loop 36
# Loop 37
# Loop 38
# Loop 39
# Loop 40
# Loop 41
# Loop 42
# Loop 43
# Loop 44
# Loop 45
# Loop 46
# Loop 47
# Loop 48
# Loop 49
# Loop 50
# Loop 51
# Loop 52
# Loop 53
# Loop 54
# Loop 55
# Loop 56
# Loop 57
# Loop 58
# Loop 59
# Loop 60
# Loop 61
# Loop 62
# Loop 63
# Loop 64
# Loop 65
# Loop 66
# Loop 67
# Loop 68
# Loop 69
# Loop 70
# Loop 71
# Loop 72
# Loop 73
# Loop 74
# Loop 75
# Loop 76
# Loop 77
# Loop 78
# Loop 79
# Loop 80
# Loop 81
# Loop 82
# Loop 83
# Loop 84
# Loop 85
# Loop 86
# Loop 87
# Loop 88
# Loop 89
# Loop 90
# Loop 91
# Loop 92
# Loop 93
# Loop 94
# Loop 95
# Loop 96
# Loop 97
# Loop 98
# Loop 99
# ...

# %%
xy_het_ticks = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5445016, 
                      nrows = 1650 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, delim_whitespace= True, usecols = [1])

fig, ax = plt.subplots()
plt.pcolormesh(xy_het_ticks.transpose(),xy_het_ticks,therm_het_phi_matrix,snap = True,shading = 'auto',cmap = 'magma')
plt.colorbar()
plt.title('Thermal Flux: Heterogenized')
plt.xlabel("Position [cm]")
plt.ylabel("Position [cm]")
ax.set_aspect('equal')
plt.savefig('therm_xy_plane_het.png',dpi = 600)

# %%
fast_het_xy_plane = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 2722507,
                                nrows = 2722500,index_col = False, header = None, engine = 'python',skip_blank_lines = True,
                                error_bad_lines = False, delim_whitespace= True, usecols = [8,9,10,11])

fast_het_phi_matrix = []
for i in range(1650):
    temp = []
    for j in range(1650):
        key = i*1650 + j
        temp.append(fast_het_xy_plane[fast_het_xy_plane.loc[:,8] == i + 1].loc[key,10])
    print("Loop " + str(i)) 
    fast_het_phi_matrix.append(temp)
# Out:
# Loop 0
# Loop 1
# Loop 2
# Loop 3
# Loop 4
# Loop 5
# Loop 6
# Loop 7
# Loop 8
# Loop 9
# Loop 10
# Loop 11
# Loop 12
# Loop 13
# Loop 14
# Loop 15
# Loop 16
# Loop 17
# Loop 18
# Loop 19
# Loop 20
# Loop 21
# Loop 22
# Loop 23
# Loop 24
# Loop 25
# Loop 26
# Loop 27
# Loop 28
# Loop 29
# Loop 30
# Loop 31
# Loop 32
# Loop 33
# Loop 34
# Loop 35
# Loop 36
# Loop 37
# Loop 38
# Loop 39
# Loop 40
# Loop 41
# Loop 42
# Loop 43
# Loop 44
# Loop 45
# Loop 46
# Loop 47
# Loop 48
# Loop 49
# Loop 50
# Loop 51
# Loop 52
# Loop 53
# Loop 54
# Loop 55
# Loop 56
# Loop 57
# Loop 58
# Loop 59
# Loop 60
# Loop 61
# Loop 62
# Loop 63
# Loop 64
# Loop 65
# Loop 66
# Loop 67
# Loop 68
# Loop 69
# Loop 70
# Loop 71
# Loop 72
# Loop 73
# Loop 74
# Loop 75
# Loop 76
# Loop 77
# Loop 78
# Loop 79
# Loop 80
# Loop 81
# Loop 82
# Loop 83
# Loop 84
# Loop 85
# Loop 86
# Loop 87
# Loop 88
# Loop 89
# Loop 90
# Loop 91
# Loop 92
# Loop 93
# Loop 94
# Loop 95
# Loop 96
# Loop 97
# Loop 98
# Loop 99
# ...

# %%
xy_het_ticks = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5445016, 
                      nrows = 1650 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      error_bad_lines = False, delim_whitespace= True, usecols = [1])

fig, ax = plt.subplots()
plt.pcolormesh(xy_het_ticks.transpose(),xy_het_ticks,fast_het_phi_matrix,snap = True,shading = 'auto',cmap = 'magma')
plt.colorbar()
plt.title('Fast Flux: Heterogenized')
plt.xlabel("Position [cm]")
plt.ylabel("Position [cm]")
ax.set_aspect('equal')
plt.savefig('fast_xy_plane_het.png',dpi = 600)

# %%
e_het_ticks = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5458565, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      delim_whitespace= True,error_bad_lines = False, usecols = [1])

core_het_spec = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5458246, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      delim_whitespace= True,error_bad_lines = False, usecols = [10,11])

fresh_het_spec = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5458883, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      delim_whitespace= True,error_bad_lines = False, usecols = [10,11])

six_het_spec = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5459520, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      delim_whitespace= True,error_bad_lines = False, usecols = [10,11])

cool_het_spec = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5460157, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      delim_whitespace= True,error_bad_lines = False, usecols = [10,11])

reflec_het_spec = pd.read_csv("htgr-20/unhomogenized/htgr-20-full-core-unhomogenized.inp_det0.m",skiprows = 5460794, 
                      nrows = 314 ,index_col = False, header = None, engine = 'python',skip_blank_lines = True, 
                      delim_whitespace= True,error_bad_lines = False, usecols = [10,11])

# %%
core_het_err = []

for i,v in enumerate(core_het_spec[11]):
    core_het_err.append(v*core_het_spec[10][i])

plt.errorbar(e_het_ticks[1],core_het_spec[10],yerr= core_het_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Heterogenized Core")
plt.xlabel('Energy [MeV]')
plt.savefig('core_spec_het.png',dpi = 600)

# %%
fresh_het_err = []

for i,v in enumerate(fresh_het_spec[11]):
    fresh_het_err.append(v*fresh_het_spec[10][i])

plt.errorbar(e_het_ticks[1],fresh_het_spec[10],yerr= fresh_het_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Heterogenized Fresh Pebble")
plt.xlabel('Energy [MeV]')
plt.savefig('fresh_spec_het.png',dpi = 600)

# %%
six_het_err = []

for i,v in enumerate(six_het_spec[11]):
    six_het_err.append(v*six_het_spec[10][i])

plt.errorbar(e_het_ticks[1],six_het_spec[10],yerr= six_het_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Heterogenized 6-Pass Pebble")
plt.xlabel('Energy [MeV]')
plt.savefig('6_spec_het.png',dpi = 600)

# %%
cool_het_err = []

for i,v in enumerate(cool_het_spec[11]):
    cool_het_err.append(v*cool_het_spec[10][i])

plt.errorbar(e_het_ticks[1],cool_het_spec[10],yerr= cool_het_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Heterogenized Coolant")
plt.xlabel('Energy [MeV]')
plt.savefig('cool_spec_het.png',dpi = 600)

# %%
reflec_het_err = []

for i,v in enumerate(reflec_het_spec[11]):
    reflec_het_err.append(v*reflec_het_spec[10][i])

plt.errorbar(e_het_ticks[1],reflec_het_spec[10],yerr= reflec_het_err,ecolor='black', linewidth = 0.6)
plt.xscale('log')
plt.title("Energy Spectrum: Heterogenized Reflector")
plt.xlabel('Energy [MeV]')
plt.savefig('reflect_spec_het.png',dpi = 600)

# %%
# difference plots: (hom-het)/het for values, see error prop. formulas

# %%
#these are all het vs hom

rel_diff_therm = []
rel_diff_err_therm = []

for i, v in enumerate(rb_het_therm):
    
    rel_diff_therm.append((rb_therm[i]-v)/v)
    
    rel_diff_err_therm.append( (rb_err_therm[i]+rb_het_err_therm[i] - 
                                (rb_het_err_therm[i]/v)*(rb_therm[i]-v) )/(v + rb_het_err_therm[i]) )
plt.errorbar(centers,rel_diff_therm,yerr=rel_diff_err_therm,ecolor='black',
             barsabove = True,errorevery = 3, linewidth = 0.6)
plt.xlabel('X Position [cm]')
plt.ylabel('Relative Difference')
plt.title('Relative Difference: Thermal Flux')
plt.savefig('reldiff_therm_flux.png',dpi = 600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-854c501da635> in <module>
#       4 rel_diff_err_therm = []
#       5
# ----> 6 for i, v in enumerate(rb_het_therm):
#       7
#       8     rel_diff_therm.append((rb_therm[i]-v)/v)
#
# NameError: name 'rb_het_therm' is not defined

# %%
rel_diff_fast = []
rel_diff_err_fast = []

for i, v in enumerate(rb_het_fast):
    
    rel_diff_fast.append((rb_fast[i]-v)/v)
    
    rel_diff_err_fast.append( (rb_err_fast[i]+rb_het_err_fast[i] - 
                                (rb_het_err_fast[i]/v)*(rb_fast[i]-v) )/(v + rb_het_err_fast[i]) )
plt.errorbar(centers,rel_diff_fast,yerr=rel_diff_err_fast,ecolor='black',
             barsabove = True,errorevery = 3, linewidth = 0.6)
plt.xlabel('X Position [cm]')
plt.ylabel('Relative Difference')
plt.title('Relative Difference: Fast Flux')
plt.savefig('reldiff_fast_flux.png',dpi = 600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-91b43eb44416> in <module>
#       2 rel_diff_err_fast = []
#       3
# ----> 4 for i, v in enumerate(rb_het_fast):
#       5
#       6     rel_diff_fast.append((rb_fast[i]-v)/v)
#
# NameError: name 'rb_het_fast' is not defined

# %%
#these are all het vs hom

rel_diff_core = []
rel_diff_err_core= []

for i, v in enumerate(core_het_spec[10]):
    
    rel_diff_core.append((core_spec[10][i]-v)/v)
    
    rel_diff_err_core.append( (core_err[i]+core_het_err[i] - 
                                (core_het_err[i]/v)*(core_spec[10][i]-v) )/(v + core_het_err[i]) )
plt.errorbar(e_ticks[1],rel_diff_core,yerr=rel_diff_err_core,ecolor='black',
             barsabove = True,errorevery = 3, linewidth = 0.6)
plt.xlabel('Energy [MeV]')
plt.ylabel('Relative Difference')
plt.title('Relative Difference: Core Spectrum')
plt.xscale('log')
#plt.yscale('log')
plt.savefig('reldiff_core_spec.png',dpi = 600)
# Out:
# <ipython-input-22-e9ddaa4066d4>:8: RuntimeWarning: invalid value encountered in double_scalars
#   rel_diff_core.append((core_spec[10][i]-v)/v)
# <ipython-input-22-e9ddaa4066d4>:11: RuntimeWarning: invalid value encountered in double_scalars
#   (core_het_err[i]/v)*(core_spec[10][i]-v) )/(v + core_het_err[i]) )

# %%
#these are all het vs hom

rel_diff_fresh= []
rel_diff_err_fresh= []

for i, v in enumerate(fresh_het_spec[10]):
    
    rel_diff_fresh.append((fresh_spec[10][i]-v)/v)
    
    rel_diff_err_fresh.append( (fresh_err[i]+fresh_het_err[i] - 
                                (fresh_het_err[i]/v)*(fresh_spec[10][i]-v) )/(v + fresh_het_err[i]) )
plt.errorbar(e_ticks[1],rel_diff_fresh,yerr=rel_diff_err_fresh,ecolor='black',
             barsabove = True,errorevery = 3, linewidth = 0.6)
plt.xlabel('Energy [MeV]')
plt.ylabel('Relative Difference')
plt.title('Relative Difference: Fresh Pebble Spectrum')
plt.xscale('log')
#plt.yscale('log')
plt.savefig('reldiff_fresh_spec.png',dpi = 600)
# Out:
# <ipython-input-23-0ac2d3cc2cad>:8: RuntimeWarning: invalid value encountered in double_scalars
#   rel_diff_fresh.append((fresh_spec[10][i]-v)/v)
# <ipython-input-23-0ac2d3cc2cad>:11: RuntimeWarning: invalid value encountered in double_scalars
#   (fresh_het_err[i]/v)*(fresh_spec[10][i]-v) )/(v + fresh_het_err[i]) )
# <ipython-input-23-0ac2d3cc2cad>:8: RuntimeWarning: divide by zero encountered in double_scalars
#   rel_diff_fresh.append((fresh_spec[10][i]-v)/v)

# %%
#these are all het vs hom

rel_diff_six = []
rel_diff_err_six= []

for i, v in enumerate(six_het_spec[10]):
    
    rel_diff_six.append((six_spec[10][i]-v)/v)
    
    rel_diff_err_six.append( (six_err[i]+six_het_err[i] - 
                                (six_het_err[i]/v)*(six_spec[10][i]-v) )/(v + six_het_err[i]) )
plt.errorbar(e_ticks[1],rel_diff_six,yerr=rel_diff_err_six,ecolor='black',
             barsabove = True,errorevery = 1, linewidth = 0.6)
plt.xlabel('Energy [MeV]')
plt.ylabel('Relative Difference')
plt.title('Relative Difference: 6-Pass Spectrum')
plt.xscale('log')
#plt.yscale('log')
plt.savefig('reldiff_six_spec.png',dpi = 600)
# Out:
# <ipython-input-24-cb830adb932a>:8: RuntimeWarning: invalid value encountered in double_scalars
#   rel_diff_six.append((six_spec[10][i]-v)/v)
# <ipython-input-24-cb830adb932a>:11: RuntimeWarning: invalid value encountered in double_scalars
#   (six_het_err[i]/v)*(six_spec[10][i]-v) )/(v + six_het_err[i]) )
# <ipython-input-24-cb830adb932a>:8: RuntimeWarning: divide by zero encountered in double_scalars
#   rel_diff_six.append((six_spec[10][i]-v)/v)

# %%
for i,v in enumerate(rel_diff_fresh):
    if 4 < v < 5:
        print(v)
        print(i)
        print(e_ticks[1][i])
        
    else:
        pass
print()
print()
    
for i,v in enumerate(rel_diff_six):
    if 2 < v < 5:
        print(v)
        print(i)
        print(e_ticks[1][i])
        
    else:
        pass
print()
print(rel_diff_six[289])
# Out:
# 4.015887275994137
# 289
# 6.3763
#
#
# 2.692212440605068
# 233
# 0.2985
# 2.1444650058257246
# 285
# 5.2205
#
# 0.1725300578001635

# %%
#these are all het vs hom

rel_diff_cool = []
rel_diff_err_cool= []

for i, v in enumerate(cool_het_spec[10]):
    
    rel_diff_cool.append((cool_spec[10][i]-v)/v)
    
    rel_diff_err_cool.append( (cool_err[i]+cool_het_err[i] - 
                                (cool_het_err[i]/v)*(cool_spec[10][i]-v) )/(v + cool_het_err[i]) )
plt.errorbar(e_ticks[1],rel_diff_cool,yerr=rel_diff_err_cool,ecolor='black',
             barsabove = True,errorevery = 3, linewidth = 0.6)
plt.xlabel('Energy [MeV]')
plt.ylabel('Relative Difference')
plt.title('Relative Difference: Coolant Spectrum')
plt.xscale('log')
#plt.yscale('log')
plt.savefig('reldiff_cool_spec.png',dpi = 600)

# %%
#these are all het vs hom

rel_diff_reflec = []
rel_diff_err_reflec= []

for i, v in enumerate(reflec_het_spec[10]):
    
    rel_diff_reflec.append((reflec_spec[10][i]-v)/v)
    
    rel_diff_err_reflec.append( (reflec_err[i]+reflec_het_err[i] - 
                                (reflec_het_err[i]/v)*(reflec_spec[10][i]-v) )/(v + reflec_het_err[i]) )
plt.errorbar(e_ticks[1],rel_diff_reflec,yerr=rel_diff_err_reflec,ecolor='black',
             barsabove = True,errorevery = 3, linewidth = 0.6)
plt.xlabel('Energy [MeV]')
plt.ylabel('Relative Difference')
plt.title('Relative Difference: Reflector Spectrum')
plt.xscale('log')
#plt.yscale('log')
plt.savefig('reldiff_reflec_spec.png',dpi = 600)

# %%
#isotope river plots

iso_comps = pd.read_csv("htgr-20/compositions/comps.csv",engine = 'python',skip_blank_lines = True, 
                      delim_whitespace= True,error_bad_lines = False,index_col = 0)

passes = np.array([1,2,3,4,5,6])

# %%
print(iso_comps.loc['U-235',:])
# Out:
# pass1    0.155000
# pass2    0.135260
# pass3    0.116142
# pass4    0.098200
# pass5    0.081017
# pass6    0.064748
# Name: U-235, dtype: float64

# %%
plt.plot(passes,iso_comps.loc['Xe-133',:], 
         passes, iso_comps.loc['Xe-135',:], 
         passes,iso_comps.loc['Xe-136',:] )
plt.legend(['Xe-133','Xe-135','Xe-136'])
plt.yscale('log')
plt.title('Xenon')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction")
# Out:
# Text(0, 0.5, 'Atomic Fraction')

# %%
plt.stackplot(passes,iso_comps.loc['Xe-133',:], iso_comps.loc['Xe-135',:], iso_comps.loc['Xe-136',:] )
plt.legend(['Xe-133','Xe-135','Xe-136'])
plt.yscale('log')
plt.title('Xenon')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction")
# Out:
# Text(0, 0.5, 'Atomic Fraction')

# %%
ax = plt.subplot(111)
ax.set_prop_cycle('color',Pastel_6.mpl_colors)
ax.bar(passes-0.2, iso_comps.loc['Xe-133',:], width=0.2, align='center')
ax.bar(passes, iso_comps.loc['Xe-135',:], width=0.2, align='center')
ax.bar(passes+0.2, iso_comps.loc['Xe-136',:], width=0.2, align='center')
lg = plt.legend(['Xe-133','Xe-135','Xe-136'],bbox_to_anchor=(1.0, 1.0))
plt.yscale('log')
plt.title('Xenon')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction [fraction]")
plt.savefig('xenon.png',dpi = 600, 
            format='png', 
            bbox_extra_artists=(lg,), 
            bbox_inches='tight')

# %%
ax = plt.subplot(111)
ax.set_prop_cycle('color',Pastel_6.mpl_colors)
ax.bar(passes-0.2, iso_comps.loc['I-129',:], width=0.2, align='center')
ax.bar(passes, iso_comps.loc['I-130',:], width=0.2, align='center')
ax.bar(passes+0.2, iso_comps.loc['I-131',:], width=0.2, align='center')
ax.bar(passes+0.4, iso_comps.loc['I-135',:], width=0.2, align='center')
lg = plt.legend(['I-129','I-130','I-131','I-135'],bbox_to_anchor=(1.0, 1.0))
plt.yscale('log')
plt.title('Iodine')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction [fraction]")
plt.savefig('iodine.png',dpi = 600, 
            format='png', 
            bbox_extra_artists=(lg,), 
            bbox_inches='tight')

# %%
ax = plt.subplot(111)
ax.set_prop_cycle('color',Pastel_6.mpl_colors)
ax.bar(passes-0.2, iso_comps.loc['Cs-134',:], width=0.2, align='center')
ax.bar(passes, iso_comps.loc['Cs-135',:], width=0.2, align='center')
ax.bar(passes+0.2, iso_comps.loc['Cs-136',:], width=0.2, align='center')
ax.bar(passes+0.4, iso_comps.loc['Cs-137',:], width=0.2, align='center')
lg = plt.legend(['Cs-134','Cs-135','Cs-136','Cs-137'],bbox_to_anchor=(1.0, 1.0))
plt.yscale('log')
plt.title('Cesium')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction [fraction]")
plt.savefig('caesium.png',dpi = 600, 
            format='png', 
            bbox_extra_artists=(lg,), 
            bbox_inches='tight')

# %%
ax = plt.subplot(111)
ax.set_prop_cycle('color',Pastel_6.mpl_colors)
ax.bar(passes-0.3, iso_comps.loc['U-232',:], width=0.15, align='center')
ax.bar(passes-0.15, iso_comps.loc['U-233',:], width=0.15, align='center')
ax.bar(passes, iso_comps.loc['U-234',:], width=0.15, align='center')
ax.bar(passes+0.15, iso_comps.loc['U-235',:], width=0.15, align='center')
ax.bar(passes+0.3, iso_comps.loc['U-236',:], width=0.15, align='center')
ax.bar(passes+0.45, iso_comps.loc['U-237',:], width=0.15, align='center')
lg = plt.legend(['U-232','U-233','U-234','U-235','U-236','U-237'],bbox_to_anchor=(1.0, 1.0))
plt.yscale('log')
plt.title('Uranium')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction [fraction]")
plt.savefig('uranium.png',dpi = 600, 
            format='png', 
            bbox_extra_artists=(lg,), 
            bbox_inches='tight')

# %%
ax = plt.subplot(111)
ax.set_prop_cycle('color',Pastel_6.mpl_colors)
ax.bar(passes-0.2, iso_comps.loc['Pu-238',:], width=0.2, align='center')
ax.bar(passes, iso_comps.loc['Pu-239',:], width=0.2, align='center')
ax.bar(passes+0.2, iso_comps.loc['Pu-240',:], width=0.2, align='center')
ax.bar(passes+0.4, iso_comps.loc['Pu-241',:], width=0.2, align='center')
lg = plt.legend(['Pu-238','Pu-239','Pu-240','Pu-241'],bbox_to_anchor=(1.0, 1.0))
plt.yscale('log')
plt.title('Plutonium')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction [fraction]")
plt.savefig('plutonium.png',dpi = 600, 
            format='png', 
            bbox_extra_artists=(lg,), 
            bbox_inches='tight')

# %%
ax = plt.subplot(111)
ax.set_prop_cycle('color',Pastel_6.mpl_colors)
ax.bar(passes-0.3, iso_comps.loc['Th-228',:], width=0.15, align='center')
ax.bar(passes-0.15, iso_comps.loc['Th-229',:], width=0.15, align='center')
ax.bar(passes, iso_comps.loc['Th-230',:], width=0.15, align='center')
ax.bar(passes+0.15, iso_comps.loc['Th-232',:], width=0.15,align='center')
ax.bar(passes+0.3, iso_comps.loc['Th-234',:], width=0.15, align='center')
lg = plt.legend(['Th-228','Th-229','Th-230','Th-232','Th-234'],bbox_to_anchor=(1.0, 1.0))
plt.yscale('log')
plt.title('Thorium')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction [fraction]")
plt.savefig('thorium.png',dpi = 600, 
            format='png', 
            bbox_extra_artists=(lg,), 
            bbox_inches='tight')

# %%
ra_225 = iso_comps.loc['Ra-225',:]
ra_225['pass1'] =0.0
ra_225['pass2'] =0.0
ra_225['pass3'] =0.0

ax = plt.subplot(111)
ax.set_prop_cycle('color',Pastel_6.mpl_colors)
ax.bar(passes-0.2, iso_comps.loc['Ra-223',:], width=0.2, align='center')
ax.bar(passes, iso_comps.loc['Ra-224',:], width=0.2, align='center')
ax.bar(passes+0.2, ra_225, width=0.2, align='center')
ax.bar(passes+0.4, iso_comps.loc['Ra-226',:], width=0.2, align='center')
lg = plt.legend(['Ra-223','Ra-224','Ra-225','Ra-226'],bbox_to_anchor=(1.0, 1.0))
plt.yscale('log')
plt.title('Radium')
plt.xlabel("Number of Passes")
plt.ylabel("Atomic Fraction [fraction]")
plt.savefig('radium.png',dpi = 600, 
            format='png', 
            bbox_extra_artists=(lg,), 
            bbox_inches='tight')

# %%
a = 2.89894E17
aerr = 0.00088

# %%
r = 164
H = 328

# %%
sa = 2*(np.pi*r**2)  + 2*np.pi*r*H

# %%
print(str(a/sa) + " +/- " + str(aerr*a/sa))
# Out:
# 571808237565.4609 +/- 503191249.0576056

# %%
control = cv2.imread("htgr-20/full-core-control/htgr-20-full-core-control-mesh1.png")
mesh_1234560 =  cv2.imread("htgr-20/1234560/htgr-20-scrmbl-1234560.inp_mesh1.png")

diff = cv2.subtract(control,mesh_1234560)

cv2.imwrite('diff-1234560.png',diff)
# Out:
# True

# %%
mesh_2345601 =  cv2.imread("htgr-20/2345601/htgr-20-scrmbl-2345601.inp_mesh1.png")

diff = cv2.subtract(control,mesh_2345601)

cv2.imwrite('diff-2345601.png',diff)
#----------------------------------

mesh_3456012 =  cv2.imread("htgr-20/3456012/htgr-20-scrmbl-3456012.inp_mesh1.png")

diff = cv2.subtract(control,mesh_3456012)

cv2.imwrite('diff-3456012.png',diff)
#----------------------------------

mesh_4560123 =  cv2.imread("htgr-20/4560123/htgr-20-scrmbl-4560123.inp_mesh1.png")

diff = cv2.subtract(control,mesh_4560123)

cv2.imwrite('diff-4560123.png',diff)
#----------------------------------

mesh_5601234 =  cv2.imread("htgr-20/5601234/htgr-20-scrmbl-5601234.inp_mesh1.png")

diff = cv2.subtract(control,mesh_5601234)

cv2.imwrite('diff-5601234.png',diff)
#----------------------------------

mesh_6012345 =  cv2.imread("htgr-20/6012345/htgr-20-scrmbl-6012345.inp_mesh1.png")

diff = cv2.subtract(control,mesh_6012345)

cv2.imwrite('diff-6012345.png',diff)
# Out:
# True

# %%
mesh_60_120 =  cv2.imread("htgr-20/slice-60-120/htgr-20-full-core-60-120-mesh1.png")

diff = cv2.subtract(control,mesh_60_120)

cv2.imwrite('diff-60-120.png',diff)
#----------------------------------

mesh_120_180 =  cv2.imread("htgr-20/slice-120-180/htgr-20-full-core-120-180-mesh1.png")

diff = cv2.subtract(control,mesh_120_180)

cv2.imwrite('diff-120-180.png',diff)
#----------------------------------
mesh_180_240 =  cv2.imread("htgr-20/slice-180-240/htgr-20-full-core-180-240-mesh1.png")

diff = cv2.subtract(control,mesh_180_240)

cv2.imwrite('diff-180-240.png',diff)
#----------------------------------
mesh_240_300 =  cv2.imread("htgr-20/slice-240-300/htgr-20-full-core-240-300-mesh1.png")

diff = cv2.subtract(control,mesh_240_300)

cv2.imwrite('diff-240-300.png',diff)
#----------------------------------
mesh_300_360 =  cv2.imread("htgr-20/slice-300-360/htgr-20-full-core-300-360-mesh1.png")

diff = cv2.subtract(control,mesh_300_360)

cv2.imwrite('diff-300-360.png',diff)
#----------------------------------
# Out:
# True
